# %% [markdown]
# # Bai 01: Getting you know your Data

# %% [markdown]
# ## 1. Tong quan ve du lieu

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# *1.1 Tai du lieu vao moi truong lam viec*

# %%
df = pd.read_csv("D:\Workspace\DATA MINING\DS_Salary_For_student_2024.csv")
df.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI             NaN                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# ...

# %% [markdown]
# *2.2 Kiem tra kich thuoc du lieu*

# %%
df.shape
# Out:
# (15579, 11)

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# *2.3 Xem truoc du lieu*

# %%
df.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI             NaN                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# ...

# %%
df.tail()
# Out:
#        work_year experience_level employment_type  \
# 15574       2023               SE              FT
# 15575       2023               MI              FT
# 15576       2024               EN              FT
# 15577       2024               SE              FT
# 15578       2023               SE              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 15574                    Data Engineer  232000             USD         232000
# 15575                    Data Engineer  181500             USD         181500
# 15576                  Data Specialist   65000             USD          65000
# 15577                   Data Scientist  170000             USD         170000
# 15578  Business Intelligence Developer  102000             USD         102000
#
#       employee_residence  remote_ratio company_location company_size
# 15574                 US             0               US            M
# ...

# %%
df.sample(5)
# Out:
#        work_year experience_level employment_type  \
# 6936        2023               SE              FT
# 11627       2023               MI              FT
# 1649        2023               SE              FT
# 4926        2024               SE              FT
# 12895       2023               EN              FT
#
#                            job_title  salary salary_currency  salary_in_usd  \
# 6936                   Data Engineer  147100             USD         147100
# 11627  Business Intelligence Analyst   96000             USD          96000
# 1649                  Data Scientist  232200             USD         232200
# 4926                  Data Scientist  170000             USD         170000
# 12895  Business Intelligence Analyst   78800             USD          78800
#
#       employee_residence  remote_ratio company_location company_size
# 6936                  US             0               US            M
# ...

# %% [markdown]
# $$
# \begin{array}{|l|l|}
#     \hline
#     \textbf{Column Name} & \textbf{Description} \\
#     \hline
#     job\_title & \text{The job title or role associated with the reported salary.} \\
#     experience\_level & \text{The level of experience of the individual.} \\
#     employment\_type & \text{Indicates whether the employment is full-time, part-time, etc.} \\
#     work\_models & \text{Describes different working models (remote, on-site, hybrid). }\\
#     work\_year & \text{The specific year in which the salary information was recorded.} \\
#     employee\_residence & \text{The residence location of the employee. }\\
#     salary & \text{The reported salary in the original currency.} \\
#     salary\_currency & \text{The currency in which the salary is denominated.} \\
#     salary\_in\_usd &\text{ The converted salary in US dollars.} \\
#     company\_location & \text{The geographic location of the employing organization.} \\
#     company\_size & \text{The size of the company, categorized by the number of employees.} \\
#     \hline
# \end{array}
# $$

# %% [markdown]
# ## 2. Kiem tra du lieu cac cot

# %% [markdown]
# *2.1 Kiem tra kieu du lieu*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15579 entries, 0 to 15578
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           15579 non-null  int64
#  1   experience_level    15579 non-null  object
#  2   employment_type     14055 non-null  object
#  3   job_title           15579 non-null  object
#  4   salary              15579 non-null  int64
#  5   salary_currency     15579 non-null  object
#  6   salary_in_usd       15579 non-null  int64
#  7   employee_residence  15579 non-null  object
#  8   remote_ratio        15579 non-null  int64
#  9   company_location    15579 non-null  object
#  10  company_size        15579 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# *2.2 Chuyen doi kieu du lieu neu can*

# %% [markdown]
# ## 3. Kiem tra gia tri thieu (Missing Values)

# %% [markdown]
# *3.1 Xac dinh so luong gia tri bi thieu*

# %%
print(df.isnull().sum())
# Out:
# work_year                0
# experience_level         0
# employment_type       1524
# job_title                0
# salary                   0
# salary_currency          0
# salary_in_usd            0
# employee_residence       0
# remote_ratio             0
# company_location         0
# company_size             0
# dtype: int64

# %% [markdown]
# *3.2 Tinh ti le phan tran gia tri bi thieu*

# %%
# Đếm số lần xuất hiện của từng loại employment_type
employment_counts = df['employment_type'].value_counts()

# Vẽ biểu đồ tròn
plt.figure(figsize=(7, 7))  # Kích thước biểu đồ
plt.pie(employment_counts, labels=employment_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])

# Thêm tiêu đề
plt.title("Distribution of Employment Type")

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# *3.3 Dinh huong xu li gia tri thieu*

# %%
# df['employment_type'] co bao nhieu gia tri phan biet
employment_counts = df['employment_type'].value_counts()
employment_counts
# Out:
# FT    13994
# CT       26
# PT       24
# FL       11
# Name: employment_type, dtype: int64

# %%
# Tim gia tri pho bien nhat
most_common_value = df['employment_type'].mode()[0]
most_common_value
# Out:
# 'FT'

# %%
# Dien gia tri pho bien nhat vao cac gia tri bi thieu cua mot cot

df['employment_type'] = df['employment_type'].fillna(most_common_value)

# Kiem tra lai xem con gia tri thieu khong
print(df.isnull().sum())
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## 4. Kiem tra du lieu trung lap

# %% [markdown]
# *4.1 Phat hien du lieu trung lap*

# %%
# Kiem tra du lieu trung lap
print(df.duplicated().sum())
# Out:
# 6453

# %% [markdown]
# *4.2 Xoa du lieu trung lap*

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (9126, 11)

# %% [markdown]
# ## 5. Phan tich du lieu dang so

# %% [markdown]
# *5.1 Thong ke mo ta*

# %%
# Kiem tra cac cot so trong data frame
# Lọc cột số
numeric_cols = df.select_dtypes(include=['number']).columns
print(numeric_cols)
# Out:
# Index(['work_year', 'salary', 'salary_in_usd', 'remote_ratio'], dtype='object')

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=10, color="skyblue")
    plt.title(f"Phân phối của cột {col}")
    plt.xlabel(col)
    plt.ylabel("Tần suất")
    plt.show()

# %% [markdown]
# ## 6. Phan tich du lieu phan loai

# %%
# Chuyển work year thành dạng category
df['work_year'] = df['work_year'].astype('category')

# %%
# Chuyển cột remote_ratio có dạng phân loại
mapping = {0: 'On-site', 50: 'Hybrid', 100: 'Remote'}
df['remote_category'] = df['remote_ratio'].map(mapping)

# %%
df.head()
# Out:
#   work_year experience_level employment_type                       job_title  \
# 0      2021               MI              FT                  Data Scientist
# 1      2021               MI              FT                 BI Data Analyst
# 2      2020               MI              FT                  Data Scientist
# 3      2021               MI              FT                     ML Engineer
# 4      2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
# ...

# %%
df['remote_category'] = df['remote_category'].astype('category')

# %%
# Lọc danh sách cột có kiểu dữ liệu categorical hoặc object
categorical_cols = df.select_dtypes(include=['category']).columns

# Liệt kê tất cả các giá trị duy nhất của từng biến phân loại
unique_values = {col: df[col].unique() for col in categorical_cols}

# %%
categorical_cols
# Out:
# Index(['work_year', 'remote_category'], dtype='object')

# %%
# In kết quả
for col, values in unique_values.items():
    print(f"Cột '{col}': {values}")
# Out:
# Cột 'work_year': [2021, 2020, 2022, 2023, 2024]
# Categories (5, int64): [2020, 2021, 2022, 2023, 2024]
# Cột 'remote_category': ['Remote', 'Hybrid', 'On-site']
# Categories (3, object): ['Hybrid', 'On-site', 'Remote']

# %%
# Dem so luong kinh nghiem va ve pie chart

# Đếm số lượng từng mức kinh nghiệm
experience_counts = df['experience_level'].value_counts()

# Vẽ biểu đồ tròn
plt.figure(figsize=(6,6))
plt.pie(experience_counts, labels=experience_counts.index, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'salmon'], startangle=140)
plt.title("Tỷ lệ các cấp độ kinh nghiệm (Experience Level)")
plt.show()

# %%
# Mapping job titles to job categories.
def map_job_title(df, original_column='job_title', new_column='job_category'):

    # Define the mapping dictionary
    job_title_mapping = {
        'data analyst': 'Data Analyst',
        'bi analyst': 'Data Analyst',
        'analytics': 'Data Analyst',
        'data scientist': 'Data Scientist',
        'data science': 'Data Scientist',
        'decision scientist': 'Data Scientist',
        'data engineer': 'Data Engineer',
        'etl': 'Data Engineer',
        'pipeline': 'Data Engineer',
        'machine learning': 'ML Engineer',
        'ml': 'ML Engineer',
        'deep learning': 'ML Engineer',
        'ai': 'ML Engineer',
        'data architect': 'Data Engineer',
        'big data': 'Data Engineer',
        'cloud data': 'Data Engineer',
        'data manager': 'Data Engineer',
        'head of data': 'Data Engineer',
        'director': 'Data Engineer',
        'bi developer': 'Data Analyst',
        'power bi': 'Data Analyst',
        'business intelligence': 'Data Analyst',
        'research scientist': 'Data Scientist',
        'research engineer': 'Data Scientist',
        'statistician': 'Data Analyst',
        'quantitative': 'Data Analyst',
        'computational biologist': 'Data Scientist',
        'robotics': 'Data Engineer',
        'nlp': 'Data Engineer',
        'applied scientist': 'Data Scientist',
        'research analyst': 'Data Analyst',
        'data specialist ': 'Data Scientist',
        'data modeler': 'Data Engineer',
    }

    # Convert job titles to lowercase and map them to broader categories
    df[new_column] = df[original_column].str.lower().apply(
        lambda title: next((v for k, v in job_title_mapping.items() if k in title), 'Data Scientist')
    )
    return df

# Example usage
df_ex = map_job_title(df)

# %%
df_ex.head()
# Out:
#   work_year experience_level employment_type                       job_title  \
# 0      2021               MI              FT                  Data Scientist
# 1      2021               MI              FT                 BI Data Analyst
# 2      2020               MI              FT                  Data Scientist
# 3      2021               MI              FT                     ML Engineer
# 4      2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
# ...

# %%
# Ve bieu do violin boxplot
# Vẽ biểu đồ violin boxplot
plt.figure(figsize=(8, 6))
sns.violinplot(x='job_category', y='salary_in_usd', data=df_ex, inner="box", palette="Set2")

# Tùy chỉnh trục x để chữ không bị chồng lên nhau
plt.xticks(rotation=30)
plt.title("Phân phối lương theo Job Category")
plt.xlabel("Job Category")
plt.ylabel("Salary in USD")
plt.show()

# %%
# Ve bieu do violin boxplot khi loc cho EN

df_en = df_ex[df_ex['experience_level'] == 'EN']

plt.figure(figsize=(8, 6))
sns.violinplot(x='job_category', y='salary_in_usd', data=df_en, inner="box", palette="Set2")

# Tùy chỉnh trục x để chữ không bị chồng lên nhau
plt.xticks(rotation=30)
plt.title("Phân phối lương theo Job Category")
plt.xlabel("Job Category")
plt.ylabel("Salary in USD")
plt.show()

# %%
# Loc du lieu cho nam 2024
# Ve bieu do violin boxplot khi loc cho EN

df_year = df_ex[(df_ex['work_year'] == 2024) & (df_ex['experience_level'] == 'EN')]

plt.figure(figsize=(8, 6))
sns.violinplot(x='job_category', y='salary_in_usd', data=df_year, inner="box", palette="Set2")

# Tùy chỉnh trục x để chữ không bị chồng lên nhau
plt.xticks(rotation=30)
plt.title("Phân phối lương theo Job Category")
plt.xlabel("Job Category")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# ## 7. Kiem tra moi quan he giua cac bien

# %%
job_category_by_employment_type = pd.crosstab(df_ex['employment_type'], df_ex['job_category'])

# %%
# Create the heatmap
plt.figure(figsize=(10, 7.5))  # Set figure size
sns.heatmap(
    job_category_by_employment_type, 
    annot=True, cmap='Purples', fmt='d', linewidths=0.5
)

# Set title and labels
plt.title("Quan hệ giữa loại công việc & lĩnh vực theo số bài đăng", fontsize=18, color='white', pad=30)
plt.xlabel("Job Category", fontsize=14, labelpad=10, color='white')
plt.ylabel("Employment Type", fontsize=14, labelpad=10, color='white')

# Set tick parameters
plt.xticks(rotation=45, fontsize=12, color='white')
plt.yticks(rotation=0, fontsize=12, color='white')

# Set background color similar to Plotly Dark theme
plt.gca().set_facecolor('#000000')

# Display the chart
plt.show()
